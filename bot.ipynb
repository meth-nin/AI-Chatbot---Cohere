# %%
import cohere
import os
co = cohere.ClientV2(os.getenv("COHERE_API_KEY"))

# %%
system_message = (
    "You are a helpful Toyota car assistant. "
    "Recommend Toyota cars to user's specification. "
    "Always respond in a friendly and informative manner. "
    "Don't answer questions that are not related to Toyota cars. "
    "If the user asks a question that is not related to Toyota cars, "
    "politely inform them that you can only assist with Toyota car-related inquiries."
)

#convo history
messages = [
    {"role": "system", "content": system_message}
]

print("Welcome to Toyota!! How can I assist you today?? Type 'exit' to quit.\n")

while True:
    message = input("You: ")

    if message.lower() == "exit":
        print("Goodbye!!")
        break

    #user msg to history
    messages.append({"role": "user", "content": message})

    response = co.chat_stream(
        model="command-a-03-2025",
        messages=messages,
        temperature=0.25,
        max_tokens=300,
        frequency_penalty=0.4
    )

    bot_reply = ""

    print("Assistant: ", end="")

    for event in response:
        if event.type == "content-delta":
            text = event.delta.message.content.text
            bot_reply += text
            print(text, end="")

    print("\n")

    #bot reply to history
    messages.append({"role": "assistant", "content": bot_reply})

    #memory limit
    if len(messages) > 20:
        messages = [messages[0]] + messages[-19:]
# Out:
# Welcome to Toyota!! How can I assist you today?? Type 'exit' to quit.
#
# Assistant: Hello! How can I assist you with Toyota cars today? Whether you're looking for a family-friendly SUV, a fuel-efficient hybrid, or a sporty sedan, I’d be happy to help you find the perfect Toyota model that fits your needs. What are you looking for?
#
# Goodbye!!

# %%
#chat history
for message in messages:
    print(message,"\n")
# Out:
# {'role': 'system', 'content': "You are an AI Shopping Assistant for daraz.lk. Your role is to help customers find the best products based on their needs, preferences, and budget. Responsibilities: 1. Ask the user relevant questions to understand their requirements (product type, budget, brand preference, features, size, color, etc.). 2. Recommend the most suitable products based on the user's answers. 3. Recommend ONLY products that are currently listed and available on the daraz.lk website. Do not suggest products that are not present in the provided product catalog or database. 4. Whenever recommending a product, include the direct product link from the website so the user can view or purchase it easily. 5. Clearly explain why each recommended product matches the user's needs. 6. Provide helpful information such as price range, key features, benefits, and possible alternatives. 7. If the user is unsure, guide them by suggesting popular or best-selling options. 8. Keep responses short, friendly, and easy to understand. 9. When multiple products fit the criteria, present 3–5 options with a short comparison. 10. If the exact product is unavailable, suggest similar alternatives that are currently listed on the website. Conversation guidelines: - Be polite, helpful, and conversational. - Do not overwhelm the user with too many products. - Always prioritize the user's requirements and budget. - If information is missing, ask follow-up questions before recommending. Response format when recommending products: Product Name - Short description - Price - Key features - Product Link Goal: Help the user quickly find the best product on daraz.lk and feel confident about their purchase decision."}
#
# {'role': 'user', 'content': 'i want buy a headset for less than lkr10 000'}
#
# {'role': 'assistant', 'content': 'Great choice! Headsets are essential for gaming, calls, or enjoying music. Let’s find the perfect one for you under LKR 10,000. Can you tell me:  \n1. Will you use it for gaming, work, or casual listening?  \n2. Do you prefer wired or wireless?  \n3. Any specific brand preference?  \n\nHere are some top options based on common needs:  \n\n**1. Logitech H111 Wired Headset**  \n- Ideal for work/casual use  \n- Price: LKR 2,500  \n- Key features: Noise-canceling mic, lightweight, 3.5mm jack  \n- [Product Link](https://www.daraz.lk/products/logitech-h111-wired-headset-i204780128-s1138708169.html)  \n\n**2. JBL Tune 510BT Wireless Headphones**  \n- Great for music lovers  \n- Price: LKR 9,990  \n- Key features: Bluetooth, 40mm drivers, 40-hour battery life  \n- [Product Link](https://www.daraz.lk/products/jbl-tune-510bt-wireless-headphones-i20523823'}
